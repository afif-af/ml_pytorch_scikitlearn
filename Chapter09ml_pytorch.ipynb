# %% [markdown]
# <a href="https://colab.research.google.com/github/afif-af/ml_pytorch_scikitlearn/blob/main/Chapter09ml_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
columns = ['Overall Qual', 'Overall Cond', 'Gr Liv Area',
'Central Air', 'Total Bsmt SF', 'SalePrice']

# %%
df = pd.read_csv('http://jse.amstat.org/v19n3/decock/AmesHousing.txt',
                sep='\t',
                usecols=columns)

df.head()
# Out:
#    Overall Qual  Overall Cond  Total Bsmt SF Central Air  Gr Liv Area  \
# 0             6             5         1080.0           Y         1656
# 1             5             6          882.0           Y          896
# 2             6             6         1329.0           Y         1329
# 3             7             5         2110.0           Y         2110
# 4             5             5          928.0           Y         1629
#
#    SalePrice
# 0     215000
# 1     105000
# 2     172000
# 3     244000
# 4     189900
